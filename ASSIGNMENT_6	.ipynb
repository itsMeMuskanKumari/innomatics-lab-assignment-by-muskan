# %% [markdown]
# <a href="https://colab.research.google.com/github/itsMeMuskanKumari/innomatics-lab-assignment-by-muskan/blob/main/ASSIGNMENT_6%09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Smart Parking Lot Management System

# %%
def smart_parking(capacity, logs):
    parked = 0
    peak = 0

    for log in logs:
        if log == "IN":
            parked += 1
        elif log == "OUT" and parked > 0:
            parked -= 1

        if parked > peak:
            peak = parked

    print("Currently Parked Vehicles:", parked)

    if parked > capacity:
        print("Parking Status: Full (Over Capacity Alert!)")
    else:
        print("Parking Status: Available")

    print("Peak Parking Usage:", peak)


# Sample Input
smart_parking(50, ["IN", "IN", "IN", "OUT", "IN", "IN", "OUT"])
# Out:
# Currently Parked Vehicles: 3
# Parking Status: Available
# Peak Parking Usage: 4

# %% [markdown]
# Problem 2: Online Food Delivery Time Estimator

# %%
def estimate_delivery(distance, traffic, weather):
    base_time = distance * 5   # 5 minutes per km

    # Traffic delay
    if traffic == "High":
        base_time += 15
    elif traffic == "Medium":
        base_time += 10

    # Weather delay
    if weather == "Rainy":
        base_time += 10
    elif weather == "Stormy":
        base_time += 20

    print("Estimated Delivery Time:", base_time, "minutes")


# Sample Input
estimate_delivery(8, "High", "Rainy")
# Out:
# Estimated Delivery Time: 65 minutes

# %% [markdown]
# Problem 3: Movie Theatre Seat Occupancy Analyzer

# %%
def seat_occupancy(total_seats, booked_seats):
    booked_count = len(booked_seats)
    occupancy = (booked_count / total_seats) * 100

    print("Occupancy:", int(occupancy), "%")

    if occupancy == 100:
        print("Show Status: Housefull")
    elif occupancy >= 75:
        print("Show Status: Almost Full")
    else:
        print("Show Status: Seats Available")


# Sample Input (150 booked seats)
seat_occupancy(200, [1]*150)
# Out:
# Occupancy: 75 %
# Show Status: Almost Full

# %% [markdown]
# Problem 4: Cloud Server Load Classification System

# %%
def server_load(cpu_readings):
    total = 0

    for reading in cpu_readings:
        total += reading

    average = total / len(cpu_readings)

    print("Average CPU Load:", int(average), "%")

    if average < 50:
        print("Server Status: Normal")
    elif 50 <= average <= 80:
        print("Server Status: Warning")
    else:
        print("Server Status: Critical")


# Sample Input
server_load([45, 60, 70, 85, 90])
# Out:
# Average CPU Load: 70 %
# Server Status: Warning

# %% [markdown]
# Problem 5: Smart Classroom Resource Usage Monitor

# %%
def resource_monitor(usage):
    overused = []

    for resource, hours in usage.items():
        if hours > 8:   # Overuse threshold
            overused.append(resource)

    if overused:
        print("Overused Resources:", ", ".join(overused))
        print("Energy Alert: Yes")
    else:
        print("Overused Resources: None")
        print("Energy Alert: No")


# Sample Input
usage_data = {
    "Projector": 6,
    "AC": 9,
    "Lights": 4
}

resource_monitor(usage_data)
# Out:
# Overused Resources: AC
# Energy Alert: Yes

# %% [markdown]
# Problem 6: Online Event Registration Capacity Controller

# %%
def event_registration(capacity, registrations):
    if registrations > capacity:
        confirmed = capacity
        waitlisted = registrations - capacity
        status = "Closed"
    else:
        confirmed = registrations
        waitlisted = 0
        status = "Open"

    print("Confirmed Registrations:", confirmed)
    print("Waitlisted Users:", waitlisted)
    print("Registration Status:", status)


# Sample Input
event_registration(100, 105)
# Out:
# Confirmed Registrations: 100
# Waitlisted Users: 5
# Registration Status: Closed
